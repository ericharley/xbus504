# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
np.random.seed(0)

# example data
#mu = 100  # mean of distribution
#sigma = 15  # standard deviation of distribution
x = 100 + 15 * np.random.randn(437)

# %%
num_bins = 20

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, normed=1)

# %%
plt.show()

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")

import matplotlib.pyplot as plt

# %%
g = sns.pairplot(iris)
plt.show()

# %%
g = sns.pairplot(iris, hue="species")
plt.show()

# %%
g = sns.pairplot(iris, size=3,
       vars=["sepal_width", "sepal_length"])

# %%
import pandas as pd
Data=pd.read_csv('/Users/harley/Desktop/xbus504/AmesHousing.txt', sep='\t')
pd.options.display.max_columns = 999
Data.head(10)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
# 5      6  527105030           60        RL          78.0      9978   Pave
# 6      7  527127150          120        RL          41.0      4920   Pave
# 7      8  527145080          120        RL          43.0      5005   Pave
# 8      9  527146030          120        RL          39.0      5389   Pave
# 9     10  527162130           60        RL          60.0      7500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# ...

# %%
theData = Data[ (Data['Lot Area']<20000) & (Data['SalePrice']<500000) ]

g = sns.pairplot(theData, size=3, vars=['Lot Area','Gr Liv Area','SalePrice'], kind="reg")

# %%
theData = Data

g = sns.pairplot(theData, size=3, vars=['Lot Area','Gr Liv Area','SalePrice'], kind="reg")
